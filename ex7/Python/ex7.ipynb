# %% [markdown]
# # Reducing dimensionality of an image with K-Means

# %%
import imageio
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

img = imageio.imread('bird_small.png') #reading the image

img = img/255 #normalizing each pixel
X = img.reshape(img.shape[0]*img.shape[1], 3) #reshape image in a Nx3 matrix

k_means = KMeans(n_clusters=16).fit(X) #k-means from sklearn with 16 clusters/colors

idx = k_means.labels_ #getting cluster for each rgb pixel
centroids = k_means.cluster_centers_ #getting means from each cluster

X_rec = centroids[idx,:] #recovering the image

X_rec = X_rec.reshape(img.shape[0], img.shape[1], 3) #reshaping to the original size

plt.figure(figsize=(12,12))
plt.subplot(1,2,1)
plt.title('Original')
plt.imshow(img)

plt.subplot(1,2,2)
plt.title('New image')
plt.imshow(X_rec)
